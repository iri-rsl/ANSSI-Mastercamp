# %%
# Necessary imports in general
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Step 1 : Extraction of RSS Flow

# %% [markdown]
# ## Getting the list of files' name

# %%
import os
# adapt path name 
path = "data_pour_TD_final/"
avis_list = os.listdir(path+"avis")
alert_list = os.listdir(path+"alertes")
mitre_list = os.listdir(path+"mitre")
first_list = os.listdir(path+"first")

# %%
# will list all dictionnaries in this list because it's cheaper than growing the data frame
cve_list = []

# %% [markdown]
# ## Get the information for avis

# %%
for avis_id in avis_list:
    with open(path+"avis/"+avis_id, 'r') as f:
        data = json.load(f)
        for cve in data["cves"]:
            # basic info
            cve_id = cve['name']
            dico = {
                'id': avis_id,
                'title': '',
                'type': 'Avis',
                'publication_date': None,
                'cve_id': cve_id,
                'original_link': None,
                'epss' : np.nan,
                'description': None,
                'cwe': 'Non disponible',
                'cwe_desc' : 'Non disponible',
                'vendor': [],
                'product': [],
                'affected_versions': [],
                'cvss': np.nan,
                'severity': None
            }
            # other info from avis
            if data['vendor_advisories'] and 'title' in data['vendor_advisories'][0]:
                dico['title'] = data['vendor_advisories'][0]['title']
            if data['vendor_advisories'] and 'published_at' in data['vendor_advisories'][0]:
                dico['publication_date'] = data['vendor_advisories'][0]['published_at']
            if data['vendor_advisories'] and 'url' in data['vendor_advisories'][0]:
                dico['original_link'] = data['vendor_advisories'][0]['url']
            # info from first
            if cve_id in first_list:
                with open(path+"first/"+cve_id, 'r') as f1:
                    data_first = json.load(f1)
                    if data_first['data'] and 'epss' in data_first['data'][0]:
                        dico['epss'] = data_first['data'][0]['epss']
                    
            # info from mitre
            if cve_id in mitre_list :
                with open(path+"mitre/"+cve_id, 'r') as f2:
                    data_mitre = json.load(f2)
                    if 'containers' in data_mitre.keys() and 'descriptions' in data_mitre['containers']['cna'].keys():
                        dico['description'] = data_mitre['containers']['cna']['descriptions'][0]['value']
    
                        # getting cwe
                        problemtype = data_mitre["containers"]["cna"].get("problemTypes", {})
                        if problemtype and "descriptions" in problemtype[0].keys(): 
                            dico['cwe'] = problemtype[0]["descriptions"][0].get("cweId", "Non disponible") 
                            dico['cwe_desc']=problemtype[0]["descriptions"][0].get("description", "Non disponible")
    
                        # getting affected products
                        affected = data_mitre['containers']['cna']['affected']
                        for product in affected:
                            if 'vendor' in product.keys() and product['vendor'] not in dico['vendor']:
                                dico['vendor'].append(product['vendor'])
                            if 'product' in product.keys() and product['product'] not in dico['product']:
                                dico['product'].append(product['product'])
                            if 'versions' in product:
                                dico['affected_versions'] = [v["version"] for v in product["versions"] if v["status"] == "affected"]
    
                        # getting cvss score and severity
                        keys = ['cvssV3_0', 'cvssV3_1', 'cvssV2', 'cvssV4_0']
                        if 'metrics' in data_mitre['containers']['cna'].keys():
                            cvss_info = data_mitre['containers']['cna']['metrics'][0]
                            for key in keys :
                                if key in cvss_info.keys():
                                    dico['cvss'] = cvss_info[key]['baseScore']
                                    dico['severity'] = cvss_info[key]['baseSeverity']
            cve_list.append(dico)

# %% [markdown]
# ## Get the information for alertes

# %%
for alert_id in alert_list:
    with open(path+"alertes/"+alert_id, 'r') as f:
        data = json.load(f)
        for cve in data["cves"]:
            # basic info
            cve_id = cve['name']
            dico = {
                'id': alert_id,
                'title': '',
                'type': 'Alerte',
                'publication_date': None,
                'cve_id': cve_id,
                'original_link': None,
                'epss' : np.nan,
                'description': None,
                'cwe': 'Non disponible',
                'cwe_desc' : 'Non disponible',
                'vendor': [],
                'product': [],
                'affected_versions': [],
                'cvss': np.nan,
                'severity': None
            }
            # other info from avis
            if data['vendor_advisories'] and 'title' in data['vendor_advisories'][0]:
                dico['title'] = data['vendor_advisories'][0]['title']
            if data['vendor_advisories'] and 'published_at' in data['vendor_advisories'][0]:
                dico['publication_date'] = data['vendor_advisories'][0]['published_at']
            if data['vendor_advisories'] and 'url' in data['vendor_advisories'][0]:
                dico['original_link'] = data['vendor_advisories'][0]['url']
            # info from first
            if cve_id in first_list:
                with open(path+"first/"+cve_id, 'r') as f1:
                    data_first = json.load(f1)
                    if data_first['data'] and 'epss' in data_first['data'][0]:
                        dico['epss'] = data_first['data'][0]['epss']
                    
            # info from mitre
            if cve_id in mitre_list :
                with open(path+"mitre/"+cve_id, 'r') as f2:
                    data_mitre = json.load(f2)
                    if 'containers' in data_mitre.keys() and 'descriptions' in data_mitre['containers']['cna'].keys():
                        dico['description'] = data_mitre['containers']['cna']['descriptions'][0]['value']
    
                        # getting cwe
                        problemtype = data_mitre["containers"]["cna"].get("problemTypes", {})
                        if problemtype and "descriptions" in problemtype[0].keys(): 
                            dico['cwe'] = problemtype[0]["descriptions"][0].get("cweId", "Non disponible") 
                            dico['cwe_desc']=problemtype[0]["descriptions"][0].get("description", "Non disponible")
    
                        # getting affected products
                        affected = data_mitre['containers']['cna']['affected']
                        for product in affected:
                            if 'vendor' in product.keys() and product['vendor'] not in dico['vendor']:
                                dico['vendor'].append(product['vendor'])
                            if 'product' in product.keys() and product['product'] not in dico['product']:
                                dico['product'].append(product['product'])
                            if 'versions' in product:
                                dico['affected_versions'] = [v["version"] for v in product["versions"] if v["status"] == "affected"]
    
                        # getting cvss score and severity
                        keys = ['cvssV3_0', 'cvssV3_1', 'cvssV2', 'cvssV4_0']
                        if 'metrics' in data_mitre['containers']['cna'].keys():
                            cvss_info = data_mitre['containers']['cna']['metrics'][0]
                            for key in keys :
                                if key in cvss_info.keys():
                                    dico['cvss'] = cvss_info[key]['baseScore']
                                    dico['severity'] = cvss_info[key]['baseSeverity']
            cve_list.append(dico)

# %%
df = pd.DataFrame(cve_list)
df.head
# Out:
# <bound method NDFrame.head of                          id  \
# 0      CERTFR-2023-AVI-0001
# 1      CERTFR-2023-AVI-0002
# 2      CERTFR-2023-AVI-0002
# 3      CERTFR-2023-AVI-0002
# 4      CERTFR-2023-AVI-0002
# ...                     ...
# 60794   CERTFR-2025-ALE-005
# 60795   CERTFR-2025-ALE-006
# 60796   CERTFR-2025-ALE-007
# 60797   CERTFR-2025-ALE-007
# 60798   CERTFR-2025-ALE-008
#
#                                                    title    type  \
# 0      Bulletin de sécurité Apache 9.0.69 du 14 novem...    Avis
# 1      Bulletin de sécurité Fortinet FG-IR-22-250 du ...    Avis
# 2      Bulletin de sécurité Fortinet FG-IR-22-250 du ...    Avis
# 3      Bulletin de sécurité Fortinet FG-IR-22-250 du ...    Avis
# 4      Bulletin de sécurité Fortinet FG-IR-22-250 du ...    Avis
# ...                                                  ...     ...
# 60794                Bulletin de sécurité SAP april-2025  Alerte
# 60795         Bulletin de sécurité Fortinet FG-IR-25-254  Alerte
# 60796  Bulletin de sécurité Ivanti Security-Advisory-...  Alerte
# 60797  Bulletin de sécurité Ivanti Security-Advisory-...  Alerte
# 60798  Bulletin de sécurité Roundcube security-update...  Alerte
#
#       publication_date          cve_id  \
# 0                 None  CVE-2022-45143
# 1                 None  CVE-2022-45857
# 2                 None  CVE-2022-35845
# 3                 None  CVE-2022-39947
# 4                 None  CVE-2022-41336
# ...                ...             ...
# 60794       2025-04-24  CVE-2025-31324
# 60795       2025-05-13  CVE-2025-32756
# 60796       2025-05-13   CVE-2025-4427
# 60797       2025-05-13   CVE-2025-4428
# 60798       2025-06-01  CVE-2025-49113
#
#                                            original_link         epss  \
# 0      https://tomcat.apache.org/security-9.html#Fixe...          NaN
# 1                                                   None          NaN
# 2                                                   None          NaN
# 3                                                   None          NaN
# 4                                                   None          NaN
# ...                                                  ...          ...
# 60794   https://support.sap.com/en/my-support/knowled...  0.809970000
# 60795      https://www.fortiguard.com/psirt/FG-IR-25-254  0.088330000
# 60796  https://forums.ivanti.com/s/article/Security-A...  0.822620000
# 60797  https://forums.ivanti.com/s/article/Security-A...  0.389460000
# 60798  https://roundcube.net/news/2025/06/01/security...  0.305290000
#
#                                              description             cwe  \
# 0                                                   None  Non disponible
# 1                                                   None  Non disponible
# 2                                                   None  Non disponible
# 3                                                   None  Non disponible
# 4                                                   None  Non disponible
# ...                                                  ...             ...
# 60794  SAP NetWeaver Visual Composer Metadata Uploade...         CWE-434
# 60795  A stack-based buffer overflow vulnerability [C...         CWE-121
# 60796  An authentication bypass in the API component ...         CWE-288
# 60797  Remote Code Execution in API component in Ivan...          CWE-94
# 60798  Roundcube Webmail before 1.5.10 and 1.6.x befo...         CWE-502
#
#                                                 cwe_desc       vendor  \
# 0                                         Non disponible           []
# 1                                         Non disponible           []
# 2                                         Non disponible           []
# 3                                         Non disponible           []
# 4                                         Non disponible           []
# ...                                                  ...          ...
# 60794  CWE-434: Unrestricted Upload of File with Dang...     [SAP_SE]
# 60795              Execute unauthorized code or commands   [Fortinet]
# 60796  CWE-288: Authentication Bypass Using an Altern...     [Ivanti]
# 60797  CWE-94: Improper Control of Generation of Code...     [Ivanti]
# 60798          CWE-502 Deserialization of Untrusted Data  [Roundcube]
#
#                                                  product  \
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 60794  [SAP NetWeaver (Visual Composer development se...
# 60795  [FortiVoice, FortiRecorder, FortiMail, FortiND...
# 60796                          [Endpoint Manager Mobile]
# 60797                          [Endpoint Manager Mobile]
# 60798                                          [Webmail]
#
#            affected_versions  cvss  severity
# 0                         []   NaN      None
# 1                         []   NaN      None
# 2                         []   NaN      None
# 3                         []   NaN      None
# 4                         []   NaN      None
# ...                      ...   ...       ...
# 60794     [VCFRAMEWORK 7.50]  10.0  CRITICAL
# 60795  [2.1.0, 2.0.0, 1.1.0]   9.6  CRITICAL
# 60796                     []   5.3    MEDIUM
# 60797                     []   7.2      HIGH
# 60798             [0, 1.6.0]   9.9  CRITICAL
#
# [60799 rows x 15 columns]>

# %%
df.columns
# Out:
# Index(['id', 'title', 'type', 'publication_date', 'cve_id', 'original_link',
#        'epss', 'description', 'cwe', 'cwe_desc', 'vendor', 'product',
#        'affected_versions', 'cvss', 'severity'],
#       dtype='object')

# %%
df[10377:11000]
# Out:
#                          id  \
# 10377  CERTFR-2023-AVI-0925
# 10378  CERTFR-2023-AVI-0925
# 10379  CERTFR-2023-AVI-0925
# 10380  CERTFR-2023-AVI-0925
# 10381  CERTFR-2023-AVI-0925
# ...                     ...
# 10995  CERTFR-2023-AVI-0976
# 10996  CERTFR-2023-AVI-0976
# 10997  CERTFR-2023-AVI-0976
# 10998  CERTFR-2023-AVI-0976
# 10999  CERTFR-2023-AVI-0976
#
#                                                    title  type  \
# 10377  Bulletin de sécurité SUSE SUSE-SU-2023:4072-2 ...  Avis
# 10378  Bulletin de sécurité SUSE SUSE-SU-2023:4072-2 ...  Avis
# 10379  Bulletin de sécurité SUSE SUSE-SU-2023:4072-2 ...  Avis
# 10380  Bulletin de sécurité SUSE SUSE-SU-2023:4072-2 ...  Avis
# 10381  Bulletin de sécurité SUSE SUSE-SU-2023:4072-2 ...  Avis
# ...                                                  ...   ...
# 10995  Bulletin de sécurité IBM 7080118 du 20 novembr...  Avis
# 10996  Bulletin de sécurité IBM 7080118 du 20 novembr...  Avis
# 10997  Bulletin de sécurité IBM 7080118 du 20 novembr...  Avis
# 10998  Bulletin de sécurité IBM 7080118 du 20 novembr...  Avis
# 10999  Bulletin de sécurité IBM 7080118 du 20 novembr...  Avis
#
#       publication_date          cve_id  \
# 10377             None   CVE-2023-4155
# 10378             None   CVE-2023-4622
# 10379             None  CVE-2023-39192
# 10380             None  CVE-2023-39191
# 10381             None  CVE-2023-39194
# ...                ...             ...
# 10995             None  CVE-2020-10735
# 10996             None  CVE-2023-44487
# 10997             None  CVE-2023-26279
# 10998             None  CVE-2022-40153
# 10999             None  CVE-2021-41771
#
#                                            original_link         epss  \
# 10377  https://www.suse.com/support/update/announceme...  0.000430000
# 10378  https://www.suse.com/support/update/announceme...  0.000420000
# 10379  https://www.suse.com/support/update/announceme...  0.000090000
# 10380  https://www.suse.com/support/update/announceme...  0.004210000
# 10381  https://www.suse.com/support/update/announceme...  0.003980000
# ...                                                  ...          ...
# 10995     https://www.ibm.com/support/pages/node/7080118  0.004930000
# 10996     https://www.ibm.com/support/pages/node/7080118  0.944340000
# 10997     https://www.ibm.com/support/pages/node/7080118          NaN
# 10998     https://www.ibm.com/support/pages/node/7080118          NaN
# 10999     https://www.ibm.com/support/pages/node/7080118  0.015560000
#
#                                              description             cwe  \
# 10377  A flaw was found in KVM AMD Secure Encrypted V...         CWE-367
# 10378  A use-after-free vulnerability in the Linux ke...         CWE-416
# 10379  A flaw was found in the Netfilter subsystem in...         CWE-125
# 10380  An improper input validation flaw was found in...          CWE-20
# 10381  A flaw was found in the XFRM subsystem in the ...         CWE-125
# ...                                                  ...             ...
# 10995  A flaw was found in python. In algorithms with...  Non disponible
# 10996  The HTTP/2 protocol allows a denial of service...  Non disponible
# 10997                                               None  Non disponible
# 10998                                               None  Non disponible
# 10999  ImportedSymbols in debug/macho (for Open or Op...  Non disponible
#
#                                                 cwe_desc  \
# 10377  Time-of-check Time-of-use (TOCTOU) Race Condition
# 10378                             CWE-416 Use After Free
# 10379                                 Out-of-bounds Read
# 10380                          Improper Input Validation
# 10381                                 Out-of-bounds Read
# ...                                                  ...
# 10995                                                DoS
# 10996                                                n/a
# 10997                                     Non disponible
# 10998                                     Non disponible
# 10999                                                n/a
#
#                                                   vendor  \
# 10377  [n/a, Red Hat, Red Hat, Red Hat, Red Hat, Red ...
# 10378                                            [Linux]
# 10379  [Red Hat, Red Hat, Red Hat, Red Hat, Red Hat, ...
# 10380  [Red Hat, Red Hat, Red Hat, Red Hat, Red Hat, ...
# 10381  [Red Hat, Red Hat, Red Hat, Red Hat, Red Hat, ...
# ...                                                  ...
# 10995                                              [n/a]
# 10996                                              [n/a]
# 10997                                                 []
# 10998                                                 []
# 10999                                              [n/a]
#
#                                                  product affected_versions  \
# 10377  [kernel, Red Hat Enterprise Linux 6, Red Hat E...                []
# 10378                                           [Kernel]             [4.2]
# 10379  [Red Hat Enterprise Linux 8, Red Hat Enterpris...                []
# 10380  [Red Hat Enterprise Linux 9, Red Hat Enterpris...                []
# 10381  [Red Hat Enterprise Linux 8, Red Hat Enterpris...                []
# ...                                                  ...               ...
# 10995                                           [python]      [python 3.7]
# 10996                                              [n/a]             [n/a]
# 10997                                                 []                []
# 10998                                                 []                []
# 10999                                              [n/a]             [n/a]
#
#        cvss severity
# 10377   NaN     None
# 10378   7.8     HIGH
# 10379   NaN     None
# 10380   NaN     None
# 10381   NaN     None
# ...     ...      ...
# 10995   NaN     None
# 10996   NaN     None
# 10997   NaN     None
# 10998   NaN     None
# 10999   NaN     None
#
# [623 rows x 15 columns]

# %% [markdown]
# # Step 5 : Interpretation & Visualisation

# %% [markdown]
# ## Diagramme circulaire des types de vulnérabilités (CWE)

# %%
effectif = df['cwe'].value_counts()
graph = plt.pie(effectif, colors=sns.color_palette('pastel'), labels=effectif.index)
plt.show()
